# %%
# %matplotlib inline
import sticker
import fgsm
from utilities import query_to_labels, url_to_im
from glob import glob
from time import time
from os import remove
import numpy as np
from distill import create_distilled
import torch
from time import sleep

import matplotlib.pyplot as plt

# %%
#Save baseline once, exclude afterwards!!!
device = torch.device('cuda:0')
model = create_distilled(device)

def fgsm_test(model,bounds=[5,25]):
    convsum_base = 0
    convsum_ad = {key:0 for key in bounds}
    times = {key:0 for key in bounds}
    a = fgsm.FGSM(model=model)
    a.print = False
    imlist = glob("Val_Delete!\\*")
    for bound in bounds:
        a.bound=bound
        times[bound]=time()
        for imurl in imlist:
            conv = a.simple_attack(imurl, "temp.png")
            convsum_ad[bound] += conv
            if bound==bounds[0]:
                convsum_base += np.max(query_to_labels(imurl))
            im = url_to_im ("temp.png")
            plt.imshow(im)
            plt.show()
            print(conv)
            sleep(12)
        times[bound] = time()-times[bound]-12*len(imlist)
    try:
        remove("temp.png")
    except:
        pass
    
    print("baseline confidence: " + str(convsum_base/len(imlist)))
    
    for key in bounds: 
        print("average confidence for bound = " + str(key) + ": " + str(convsum_ad[key]/len(imlist)))
        print("time taken: " + str(times[key]) + " seconds")

# %%
fgsm_test(model)
# Out:
# 0.61283326
# 0.95771354
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-f33c4705cf83> in <module>()
# ----> 1 fgsm_test(model)
#
# <ipython-input-40-77fd5e2ea4e9> in fgsm_test(model, bounds)
#      14         times[bound]=time()
#      15         for imurl in imlist:
# ---> 16             conv = a.simple_attack(imurl, "temp.png")
#      17             convsum_ad[bound] += conv
#      18             if bound==bounds[0]:
#
# C:\Users\flodo\Documents\GitHub\Infocup_final\fgsm.py in simple_attack(self, im_url, save_url)
#     208         if self.print:
#     209             print("attacking label " + str(target_label))
# --> 210         return self.attack_on_label(im_url, save_url, target_label)
#     211
#     212     def reload_model(self, model):
#
# C:\Users\flodo\Documents\GitHub\Infocup_final\fgsm.py in attack_on_label(self, im_url, save_url, target_label)
#     171                 advers = self._create_advers([im[0]], target_label, [im[0]]).reshape((1, 3, 64, 64))
#     172             elif self.fgsm_restart == "last":
# --> 173                 advers = self._create_advers([im[-1]], target_label, [im[0]]).reshape((1, 3, 64, 64))
#     174             else:
#     175                 if self.print:
#
# C:\Users\flodo\Documents\GitHub\Infocup_final\fgsm.py in _create_advers(self, im, target_label, base)
#     136         while prob < self.target_threshold and steps < self.max_fgsm_iterations:
#     137             steps += 1
# --> 138             im, prob = self._fastgrad_step(im, target_label, base)
#     139         if self.print:
#     140             print("probability: Whitebox")
#
# C:\Users\flodo\Documents\GitHub\Infocup_final\fgsm.py in _fastgrad_step(self, im, target_label, base)
#      78
#      79     def _fastgrad_step(self, im, target_label, base):
# ---> 80         im_grad = self._get_gradient(im, target_label)
#      81         im = im + self.magnitude * np.sign(im_grad.cpu().detach().numpy())
#      82         if self.mode == "simple":
#
# C:\Users\flodo\Documents\GitHub\Infocup_final\fgsm.py in _get_gradient(self, im, target_label)
#      72         output = self.model(im_tensor)
#      73         loss = torch.take(output, torch.tensor(target_label).to(self.device))
# ---> 74         loss.backward()
#      75         im_grad = im_tensor.grad
#      76
#
# C:\Users\flodo\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# C:\Users\flodo\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
a=fgsm.FGSM()

# %%
name = "Adam_Sandler"

base_directory = "C:\\Users\\flodo\\Desktop\\Infocup_Data\\Adversarial_bases\\"
target_directory = "C:\\Users\\flodo\\Desktop\\Infocup_Data\\Advers_working\\"

imurl= base_directory+name+".png"
save_url=target_directory+name+".png"

fgsm.preview_im(imurl)
a.simple_attack(imurl,save_url)
# Out:
# Labels with highest confidence:
# Vorfahrt (label 12): 0.44052419
# Zulässige Höchstgeschwindigkeit (30) (label 1): 0.11033559
# Baustelle (label 25): 0.07293988
# Stoppschild (label 14): 0.06493238
# Vorfahrt gewähren (label 13): 0.04811269
# try attacking one of those labels!
# attacking label 12
#
# step: 1
# MSE White vs Black Box before retraining:
# 0.0252857131031
# MSE White vs Black Box after retraining:
# 0.012326393276453018
# probability: Whitebox
# 0.993827760219574
# probability: Blackbox
# 0.88649476
#
# step: 2
# MSE White vs Black Box before retraining:
# 0.0115203729361
# MSE White vs Black Box after retraining:
# 0.011275384575128555
# probability: Whitebox
# 0.9957209229469299
# probability: Blackbox
# 0.90685701
#
# step: 3
# MSE White vs Black Box before retraining:
# 0.00789679502424
# MSE White vs Black Box after retraining:
# 0.00775955431163311
# probability: Whitebox
# 0.9955862760543823
# probability: Blackbox
# 0.90741205
#
# step: 4
# MSE White vs Black Box before retraining:
# 0.00777469414029
# MSE White vs Black Box after retraining:
# 0.00763147184625268
# probability: Whitebox
# 0.995425283908844
# probability: Blackbox
# 0.90945369
#
# step: 5
# MSE White vs Black Box before retraining:
# 0.00739111495923
# MSE White vs Black Box after retraining:
# 0.007243419531732798
# probability: Whitebox
# 0.9950464963912964
# probability: Blackbox
# 0.90962815
#
# step: 6
# MSE White vs Black Box before retraining:
# 0.00729629390022
# MSE White vs Black Box after retraining:
# 0.007131803780794144
# probability: Whitebox
# 0.9945895671844482
# probability: Blackbox
# 0.91126508
#
# step: 7
# MSE White vs Black Box before retraining:
# 0.00694297016455
# MSE White vs Black Box after retraining:
# 0.006764709483832121
# probability: Whitebox
# 0.9939124584197998
# probability: Blackbox
# 0.91182345
#
# step: 8
# MSE White vs Black Box before retraining:
# 0.00673860530335
# MSE White vs Black Box after retraining:
# 0.006537696812301874
# probability: Whitebox
# 0.9931437969207764
# probability: Blackbox
# 0.91268575
#
# step: 9
# MSE White vs Black Box before retraining:
# 0.00647349731431
# MSE White vs Black Box after retraining:
# 0.0062492610886693
# probability: Whitebox
# 0.9920877814292908
# probability: Blackbox
# 0.91256911
#
# step: 10
# MSE White vs Black Box before retraining:
# 0.00632321910588
# MSE White vs Black Box after retraining:
# 0.0060648806393146515
# probability: Whitebox
# 0.9908632636070251
# probability: Blackbox
# 0.9127391
#
# convergence to target confidence failed. relax bounds, increase loop length or start with another image!
# 0.91273910000000003

# %%
a.simple_attack(im, target_label, save_url, bound=15, mode="l_inf",target_threshold=0.9,max_inner_steps=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-39a55debe8d8> in <module>()
# ----> 1 a.simple_attack(im, target_label, save_url, bound=15, mode="l_inf",target_threshold=0.9,max_inner_steps=30)
#
# NameError: name 'im' is not defined

# %%
from os import remove
try:
    remove("3123123123123112")
except(FileNotFoundError):
    print(2)
# Out:
# 2

# %%
for i in range(43):
    a.make_sticker(i,title="7_block_central")
# Out:
# Confidence for Sticker on label 2: 0.01730714
# Confidence for Sticker on label 3: 0.90082157
# Sticker saved under Quickstick\3\7_block_central0.010.90082157.png
# Confidence for Sticker on label 4: 0.09539092
# Confidence for Sticker on label 8: 0.99852258
# Sticker saved under Quickstick\8\7_block_central0.010.99852258.png
# Confidence for Sticker on label 9: 0.07509521
# Confidence for Sticker on label 10: 0.9399305
# Sticker saved under Quickstick\10\7_block_central0.010.9399305.png
# Confidence for Sticker on label 13: 0.02406728
# Confidence for Sticker on label 14: 0.29954457
# Confidence for Sticker on label 17: 0.9982937
# Sticker saved under Quickstick\17\7_block_central0.010.9982937.png
# Confidence for Sticker on label 18: 0.01623129
# Confidence for Sticker on label 19: 0.02638045
# Confidence for Sticker on label 22: 0.03525138
# Confidence for Sticker on label 25: 0.98064834
# Sticker saved under Quickstick\25\7_block_central0.010.98064834.png
# Confidence for Sticker on label 31: 0.01024869
# Confidence for Sticker on label 33: 0.0442517
# Confidence for Sticker on label 35: 0.08046709
# Confidence for Sticker on label 38: 0.68687475

# %%
print(a.queries)
# Out:
# 30

# %%
sticker.sticker_attack("C:\\Users\\flodo\\Desktop\\Infocup_Data\\Adversarial_bases\\Zaini_Abdullah.png","C:\\Users\\flodo\\Desktop\\Infocup_Data\\Advers_working\\Zaini_Abdullah_stick.png",label=10)
# Out:
# 0.99999678

# %%
5/1.2
# Out:
# 4.166666666666667
